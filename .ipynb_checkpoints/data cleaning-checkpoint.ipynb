# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set(style="darkgrid")

# %%
# # assign columns
# col_names = ["col" + str(i) for i in range(1,10)]
# load full data set and convert csv \N to NaN in pandas dataframe
AllData = pd.read_csv('lwc_data\parsed_messages.csv', sep='\""","""', engine='python', na_values='\\N')

# %%
AllData.head()
# Out:
#                  col1  col2    col3 col4              col5  \
# 0  "3399658666084059"  "44"     "1"  "m"        "soulleoo"
# 1  "3399658666083922"  "35"     "1"  "m"       "Tony_Heqi"
# 2  "3399658665799759"  "44"     "8"  "f"             "謝秋如"
# 3  "3399658665799554"  "44"     "3"  "m"       "yinjiawei"
# 4  "3399658665575454"  "31"  "1000"  "m"  "Wings_of_Winds"
#
#                                                 col6  col7  \
# 0  "一分耕耘，一分收获！//@soulleoo 的小小乐园的最具吸引力乐园为5031，超过@败...  "25"
# 1  "太给力了，是不是？//@Tony_Heqi 在达人麻将 获得了成就Good Job!，获取...  "36"
# 2                                 "3399658665799719"   NaN
# 3                                 "3399658665799504"   NaN
# 4                "为什么每次不在中国都会在他们家？@田鸡W @-RJ-爱喝乙醇的甲醇"  "12"
#
#                                                 col8  \
# 0  "一 分 耕耘 ， 一 分 收获 ！ 的 小小 乐园 的 最 具 吸引力 乐园 为 5031...
# 1  "太 给力 了 ， 是 不 是 ？ 在 达人 麻将 获得 了 成就 Good Job ， 获...
# 2                                                NaN
# 3                                                NaN
# 4                      "为什么 每 次 不 在 中国 都 会 在 他们 家 ？"
#
#                                                 col9
# 0  "一/CD 分/M 耕耘/VV ，/PU 一/CD 分/M 收获/NN ！/PU 的/DEG...
# 1  "太/AD 给力/VV 了/AS ，/PU 是/VC 不/AD 是/VC ？/PU 在/P ...
# 2                                                NaN
# 3                                                NaN
# 4  "为什么/AD 每/DT 次/M 不/AD 在/P 中国/NR 都/AD 会/VV 在/P ...

# %%
# rename columns
AllData.columns = ['MessageID', 'Province', 'City', 'Gender', 'Username', 'Message', 'NumWords', 'WithWordBounds', 'POStags']

# %%
AllData.head()
# Out:
#             MessageID Province    City Gender          Username  \
# 0  "3399658666084059"     "44"     "1"    "m"        "soulleoo"
# 1  "3399658666083922"     "35"     "1"    "m"       "Tony_Heqi"
# 2  "3399658665799759"     "44"     "8"    "f"             "謝秋如"
# 3  "3399658665799554"     "44"     "3"    "m"       "yinjiawei"
# 4  "3399658665575454"     "31"  "1000"    "m"  "Wings_of_Winds"
#
#                                              Message NumWords  \
# 0  "一分耕耘，一分收获！//@soulleoo 的小小乐园的最具吸引力乐园为5031，超过@败...     "25"
# 1  "太给力了，是不是？//@Tony_Heqi 在达人麻将 获得了成就Good Job!，获取...     "36"
# 2                                 "3399658665799719"      NaN
# 3                                 "3399658665799504"      NaN
# 4                "为什么每次不在中国都会在他们家？@田鸡W @-RJ-爱喝乙醇的甲醇"     "12"
#
#                                       WithWordBounds  \
# 0  "一 分 耕耘 ， 一 分 收获 ！ 的 小小 乐园 的 最 具 吸引力 乐园 为 5031...
# 1  "太 给力 了 ， 是 不 是 ？ 在 达人 麻将 获得 了 成就 Good Job ， 获...
# 2                                                NaN
# 3                                                NaN
# 4                      "为什么 每 次 不 在 中国 都 会 在 他们 家 ？"
#
#                                              POStags
# 0  "一/CD 分/M 耕耘/VV ，/PU 一/CD 分/M 收获/NN ！/PU 的/DEG...
# 1  "太/AD 给力/VV 了/AS ，/PU 是/VC 不/AD 是/VC ？/PU 在/P ...
# 2                                                NaN
# 3                                                NaN
# 4  "为什么/AD 每/DT 次/M 不/AD 在/P 中国/NR 都/AD 会/VV 在/P ...

# %%
AllData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5103596 entries, 0 to 5103595
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   MessageID       object
#  1   Province        object
#  2   City            object
#  3   Gender          object
#  4   Username        object
#  5   Message         object
#  6   NumWords        object
#  7   WithWordBounds  object
#  8   POStags         object
# dtypes: object(9)
# memory usage: 350.4+ MB

# %%
AllData["NumWords"] = AllData["NumWords"].str.replace("\"", "")

# %%
AllData.dropna()
# Out:
#                   MessageID Province    City Gender            Username  \
# 0        "3399658666084059"     "44"     "1"    "m"          "soulleoo"
# 1        "3399658666083922"     "35"     "1"    "m"         "Tony_Heqi"
# 4        "3399658665575454"     "31"  "1000"    "m"    "Wings_of_Winds"
# 5        "3399658665161458"     "11"  "1000"    "m"        "阿喵_Monster"
# 6        "3399658665161454"     "44"     "1"    "f"              "泽仁塔姆"
# ...                     ...      ...     ...    ...                 ...
# 5102942  "3407330739884370"     "44"    "19"    "m"            "o波子哥哥o"
# 5102976  "3407330725615495"     "44"     "9"    "f"           "1995安呆呆"
# 5103400  "3407331214191740"     "21"     "1"    "f"  "fengzhengfeilema"
# 5103474  "3407331507330625"     "44"     "1"    "m"            "张恩思的围脖"
# 5103525  "3407331478222625"    "400"    "11"    "m"           "嘉少-Vega"
#
#                                                    Message         NumWords  \
# 0        "一分耕耘，一分收获！//@soulleoo 的小小乐园的最具吸引力乐园为5031，超过@败...               25
# 1        "太给力了，是不是？//@Tony_Heqi 在达人麻将 获得了成就Good Job!，获取...               36
# 4                      "为什么每次不在中国都会在他们家？@田鸡W @-RJ-爱喝乙醇的甲醇"               12
# 5                                       "刚才那句话真的有歧义。。恩恩。。"               10
# 6                                    "某人卖萌了！哈哈~被小萝莉贴了一身贴纸"               14
# ...                                                    ...              ...
# 5102942                                          "你们那天真的友谊      就像那纯白的香草棉花糖
# 5102976                                            "一个人的所有       没有人在我心里多重要
# 5103400                                             "军回学校了             安全抵达
# 5103474                                           "有时上街买东西  销售人员用蹩脚的广式普通话接待
# 5103525                                          "无论你再如何争辩  我依旧觉得女人没有一个是可信的
#
#                                             WithWordBounds  \
# 0        "一 分 耕耘 ， 一 分 收获 ！ 的 小小 乐园 的 最 具 吸引力 乐园 为 5031...
# 1        "太 给力 了 ， 是 不 是 ？ 在 达人 麻将 获得 了 成就 Good Job ， 获...
# 4                            "为什么 每 次 不 在 中国 都 会 在 他们 家 ？"
# 5                            "刚才 那 句 话 真的 有 歧义 。 。 恩恩 。 。"
# 6                        "某 人 卖萌 了 ！ 哈哈 被 小 萝莉 贴 了 一 身 贴纸"
# ...                                                    ...
# 5102942                                       没有任何玷污。深沉的友谊
# 5102976                                       我也没在谁人的心里多重要
# 5103400                              我去问候他的同时他一口一句的离不开´你们´
# 5103474                                               听着难受
# 5103525                                一个都没有..我相信他们会认同我的观点
#
#                                                    POStags
# 0        "一/CD 分/M 耕耘/VV ，/PU 一/CD 分/M 收获/NN ！/PU 的/DEG...
# 1        "太/AD 给力/VV 了/AS ，/PU 是/VC 不/AD 是/VC ？/PU 在/P ...
# 4        "为什么/AD 每/DT 次/M 不/AD 在/P 中国/NR 都/AD 会/VV 在/P ...
# 5        "刚才/AD 那/DT 句/M 话/NN 真的/AD 有/VE 歧义/NN 。/PU 恩恩/...
# 6        "某/DT 人/NN 卖萌/VV 了/SP ！/PU 哈哈/IJ 被/SB 小/JJ 萝莉/...
# ...                                                    ...
# 5102942                                        就像那原汁原味的棉花糖
# 5102976                                            不是一切遗弃我
# 5103400                                             要不要这样啊
# 5103474                                      我就用一口纯正的广州话回答
# 5103525                                         你的请求一定会被否决
#
# [4740394 rows x 9 columns]

# %%
AllData.dropna(subset='a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-b9201b9e0eb3> in <module>
# ----> 1 AllData.dropna(subset='a')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4743         if subset is not None:
#    4744             ax = self._get_axis(agg_axis)
# -> 4745             indices = ax.get_indexer_for(subset)
#    4746             check = indices == -1
#    4747             if check.any():
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer_for(self, target, **kwargs)
#    4500         """
#    4501         if self.is_unique:
# -> 4502             return self.get_indexer(target, **kwargs)
#    4503         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#    4504         return indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2707     def get_indexer(self, target, method=None, limit=None, tolerance=None):
#    2708         method = missing.clean_reindex_fill_method(method)
# -> 2709         target = ensure_index(target)
#    2710         if tolerance is not None:
#    2711             tolerance = self._convert_tolerance(tolerance, target)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in ensure_index(index_like, copy)
#    5356             index_like = copy(index_like)
#    5357
# -> 5358     return Index(index_like)
#    5359
#    5360
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     420             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#     421         elif data is None or is_scalar(data):
# --> 422             raise cls._scalar_data_error(data)
#     423         else:
#     424             if tupleize_cols and is_list_like(data):
#
# TypeError: Index(...) must be called with a collection of some kind, 'a' was passed

# %%
AllData["NumWords"] = AllData["NumWords"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-683e0b1a334c> in <module>
# ----> 1 AllData["NumWords"] = AllData["NumWords"].astype(int)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer
